# %%
import csv
import requests
from bs4 import BeautifulSoup
import re
import sys 
import time
ranking=1
schoolList=[]

# %%
# website="https://roundranking.com/ranking/world-university-rankings.html#world-2021"

# response = requests.get(website)

# print(response.request.url)
# soup=BeautifulSoup(response.text,"html.parser")
# # print (soup)
# schoolName=soup.find_all("tr", class_="az-row-100")



# print(len(schoolName))
# for loop in range(0,200):
#   text=text[text.index('td2'):]
#   text=text[text.index('>')+1:]


import requests 
from requests_toolbelt.utils import dump

resp = requests.get('https://roundranking.com/ranking/world-university-rankings.html?year=2020#world-2020')
data = dump.dump_all(resp)
print(data.decode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-32-c8742fdf0115> in <module>()
#      17
#      18 import requests
# ---> 19 from requests_toolbelt.utils import dump
#      20
#      21 resp = requests.get('https://roundranking.com/ranking/world-university-rankings.html?year=2020#world-2020')
#
# ModuleNotFoundError: No module named 'requests_toolbelt'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
