# %%
import csv
import requests
from bs4 import BeautifulSoup
import re


response = requests.get('https://cwur.org/2021-22.php')
soup=BeautifulSoup(response.text,"html.parser")
print(soup)
x=soup.find_all("a")
# y=soup.find_all("td", class_="rate-content-cash text-right print_hide")
print(x)
# count=0
# # print(x)
# for tag in y:
#     cur=tag.text
#     if count%2==0:
#         buy.append(cur)
#     else:
#         sell.append(cur)
#     count+=1


# for tag in x:
#     country=tag.text
#     coun.append(country)
    


# with open('p9.csv', 'w', newline='') as csvfile:
#     fieldnames = ['國家', '本行買入','本行賣出']
#     writer = csv.DictWriter(csvfile, fieldnames=fieldnames) 
#     writer.writeheader()

#     for x in range(len(coun)):
#         writer.writerow({'國家': coun[x], '本行買入': buy[x], '本行賣出': sell[x]})
# Out:
# <head><title>Not Acceptable!</title></head><body><h1>Not Acceptable!</h1><p>An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.</p></body>
# []
