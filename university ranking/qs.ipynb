# %%
import csv
import requests
from bs4 import BeautifulSoup
import re
import sys 
ranking=1
schoolList=[]

# %%
website="https://www.topuniversities.com/university-rankings/world-university-rankings/2022"
response = requests.get(website)
soup=BeautifulSoup(response.text,"html.parser")
schoolName=soup.find_all("section", class_="td-wrap")
print(len(schoolName))
# Out:
# 5

# %%
for tag in schoolName:
    string=tag.text
    print(string)
# Out:
#     googletag.cmd.push(function () {
#       googletag.display('js-dfp-tag-responsive_ad_1');
#     });
#
#
#
#
#
#
#
#
#
#
#     googletag.cmd.push(function () {
#       googletag.display('js-dfp-tag-responsive_ad_2');
#     });
#
#
#
#
#
#
# Environmental Impact
# Equal Opportunities
